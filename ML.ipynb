# %%
import pandas as pd

# %%
name=pd.Series(["Yash","Dev","Ragh","Pritam"])

# %%
section = pd.Series(["A","B","C","D"])

# %%
roll_no = pd.Series(["1","2","3","4"])
marks = pd.Series(["80","90","85","91"])
percentage= pd.Series(["80%","90%","85%","91%"])

# %%
DF=pd.DataFrame({"Name": name,"Section":section,"Roll_no":roll_no,"Marks":marks,"percentage":percentage})

# %%
DF
# Out:
#      Name Section Roll_no Marks percentage
# 0    Yash       A       1    80        80%
# 1     Dev       B       2    90        90%
# 2    Ragh       C       3    85        85%
# 3  Pritam       D       4    91        91%
